# %% [markdown]
# ### 1.对于一个概率分布 $P$，其中有 $K$ 个可能的事件，每个事件的概率为 $p_i$，熵 $H(P)$ 的计算公式为:

# %% [markdown]
# $H(P) = -\sum_{i=1}^{K} p_i \cdot \log_2(p_i)$

# %% [markdown]
# $\text{Entropy} = \sum p(x) \log_2\left( \frac{1}{p(x)} \right)$
#
# 概率与惊喜程度的均值

# %% [markdown]
# ### 2.互信息的计算方式

# %%
from IPython.display import Image
Image(filename='C:\\Users\\Y.Y\\Pictures\\Jp\\互信息.png')
